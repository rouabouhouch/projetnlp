# %% [markdown]
# # 🧠 TP – Préparation du Dataset pour un Modèle NLP
#
# ---
#
# ## 1️⃣ Chargement du Dataset
#
# On lit le fichier texte prétraité ligne par ligne.
# Chaque ligne contient une phrase et son étiquette (sentiment ou émotion), séparées par un point-virgule `;`.
#
# La fonction `load_file(path)` retourne deux listes :
# - **texts** : les phrases
# - **emotions** : les étiquettes associées

# %%
def load_file(file_path, sep=";"):
    texts = []
    emotions = []
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue  # on saute les lignes vides
            parts = line.split(sep)
            if len(parts) >= 2:
                text = parts[0].strip()
                emotion = parts[1].strip()
                texts.append(text)
                emotions.append(emotion)
    return texts, emotions

texts, emotions = load_file("dataset/train.txt")
print(texts[:3])
print(emotions[:3])
# Out:
# ['i didnt feel humiliated', 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake', 'im grabbing a minute to post i feel greedy wrong']
# ['sadness', 'sadness', 'anger']

# %% [markdown]
# 📘 **Exemple de sortie :**
#
#
# ['i didnt feel humiliated',
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake',
# 'im grabbing a minute to post i feel greedy wrong']
#
# ['sadness', 'sadness', 'anger']

# %% [markdown]
# ---
#
# ## 2️⃣ Construction du Vocabulaire
#
# On crée une correspondance `mot -> id_mot` à partir de toutes les phrases du dataset.
# Chaque mot reçoit un identifiant numérique unique.
#
# On ajoute aussi deux mots spéciaux :
# - `<PAD>` : utilisé pour le **remplissage** des phrases plus courtes
# - `<UNK>` : utilisé pour les **mots inconnus**

# %%
def build_vocab(texts):
    vocab = {"<PAD>": 0, "<UNK>": 1}
    idx = 2
    for text in texts:
        for word in text.split():
            if word not in vocab:
                vocab[word] = idx
                idx += 1
    return vocab

# Exemple
vocab = build_vocab(texts)
print("Taille du vocabulaire :", len(vocab))
list(vocab.items())[:10]  # affichage partiel
# Out:
# Taille du vocabulaire : 15214
# [('<PAD>', 0),
#  ('<UNK>', 1),
#  ('i', 2),
#  ('didnt', 3),
#  ('feel', 4),
#  ('humiliated', 5),
#  ('can', 6),
#  ('go', 7),
#  ('from', 8),
#  ('feeling', 9)]

# %% [markdown]
# ## 3️⃣ Encodage One-Hot des Mots
#
# Chaque mot est représenté par un vecteur **one-hot** de taille égale à `vocab_size`.
#
# - Exemple : si `vocab = {"<PAD>":0, "<UNK>":1, "I":2, "love":3, "NLP":4}`,
#   alors `"love"` devient `[0, 0, 0, 1, 0]`.

# %%
import numpy as np

def one_hot_encode(word, vocab):
    vec = np.zeros(len(vocab), dtype=np.float32)
    idx = vocab.get(word, vocab["<UNK>"])
    vec[idx] = 1.0
    return vec

# Exemple
print(one_hot_encode("feel", vocab))
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %% [markdown]
# ## 4️⃣ Normalisation de la Longueur des Phrases (Padding)
#
# Les réseaux de neurones exigent des entrées de **même longueur**.
# On fixe donc une taille maximale `sentence_size` et :
# - on **tronque** les phrases trop longues,
# - on **remplit** les phrases plus courtes avec le mot spécial `<PAD>`.
#
# Exemple :
#
# ["I", "love", "NLP"] → ["I", "love", "NLP", "<PAD>", "<PAD>"]

# %%
def pad_sentence(words, sentence_size):
    words = words[:sentence_size]
    while len(words) < sentence_size:
        words.append("<PAD>")
    return words

def pad_all_sentences(texts, sentence_size):
    padded = []
    for text in texts:
        words = text.split()
        padded.append(pad_sentence(words, sentence_size))
    return padded

# Exemple
sentence_size = 10

padded_texts = pad_all_sentences(texts, sentence_size)
for p in padded_texts:
    print(p)
# Out:
# ['i', 'didnt', 'feel', 'humiliated', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['i', 'can', 'go', 'from', 'feeling', 'so', 'hopeless', 'to', 'so', 'damned']
# ['im', 'grabbing', 'a', 'minute', 'to', 'post', 'i', 'feel', 'greedy', 'wrong']
# ['i', 'am', 'ever', 'feeling', 'nostalgic', 'about', 'the', 'fireplace', 'i', 'will']
# ['i', 'am', 'feeling', 'grouchy', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['ive', 'been', 'feeling', 'a', 'little', 'burdened', 'lately', 'wasnt', 'sure', 'why']
# ['ive', 'been', 'taking', 'or', 'milligrams', 'or', 'times', 'recommended', 'amount', 'and']
# ['i', 'feel', 'as', 'confused', 'about', 'life', 'as', 'a', 'teenager', 'or']
# ['i', 'have', 'been', 'with', 'petronas', 'for', 'years', 'i', 'feel', 'that']
# ['i', 'feel', 'romantic', 'too', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>']
# ['i', 'feel', 'like', 'i', 'have', 'to', 'make', 'the', 'suffering', 'i']
# ...

# %% [markdown]
# ## 6️⃣ Préparation du Dataset pour le Réseau de Neurones
#
# Le réseau récurrent (RNN, LSTM, GRU, etc.) prend en entrée, **mot par mot**, un vecteur de taille `vocab_size`.
#
# ➡️ Pour un `batch_size = 10` et une `sentence_size = 20` :
# - On envoie d’abord les **10 premiers mots** de chaque phrase (shape `(10, vocab_size)`),
# - Puis les **10 seconds mots**, etc., jusqu’à 20 mots par phrase.
#
# L’idée : construire une classe `torch.utils.data.Dataset` qui :
# 1. Reçoit les phrases et leurs labels,
# 2. Fait le **padding**,
# 3. Encode chaque mot en **one-hot**,
# 4. Retourne les tenseurs utilisables par le modèle.

# %%
import numpy as np

class Dataset:
    pass  

class torch:
    class utils:
        class data:
            class Dataset:
                def __init__(self, texts, emotions, vocab, sentence_size):
                    """
                    Initialise notre dataset avec :
                    - texts : liste de phrases
                    - emotions : liste de labels associés à chaque phrase
                    - vocab : dictionnaire {mot -> id}
                    - sentence_size : longueur fixe pour chaque phrase (padding/tronquage)
                    """
                    self.texts = texts
                    self.emotions = emotions
                    self.vocab = vocab
                    self.sentence_size = sentence_size

                    # Création d’un mapping entre label texte et ID numérique
                    # Exemple : {"joy": 0, "anger": 1, "sadness": 2, ...}
                    self.labels = sorted(list(set(emotions)))
                    self.label2id = {lab: i for i, lab in enumerate(self.labels)}

                def __len__(self):
                    """
                    Retourne le nombre total d’exemples dans le dataset.
                    Permet d’utiliser len(dataset)
                    """
                    return len(self.texts)

                def __getitem__(self, idx):
                    """
                    Retourne l’échantillon numéro idx :
                    - one_hot_sentence : matrice (sentence_size, vocab_size)
                    - label : entier représentant l’émotion
                    """

                    # 1️⃣ On récupère la phrase correspondante
                    words = self.texts[idx].split()

                    # 2️⃣ Tronquage si la phrase est trop longue
                    words = words[:self.sentence_size]

                    # 3️⃣ Padding si elle est trop courte
                    words += ["<PAD>"] * (self.sentence_size - len(words))

                    # 4️⃣ Encodage one-hot mot par mot
                    one_hot_sentence = np.array([one_hot_encode(w, self.vocab) for w in words])

                    # 5️⃣ Conversion du label texte en entier
                    label = self.label2id[self.emotions[idx]]

                    return one_hot_sentence, label

# %% [markdown]
# ## ⚙️ 7️⃣ Génération manuelle des batchs
#
# Le réseau sera alimenté **par batchs** :
# au lieu d’envoyer une phrase à la fois, on regroupe plusieurs échantillons ensemble.
#
# On définit donc une fonction `generate_batches()` qui :
# 1. Parcourt le dataset par tranches de `batch_size`,
# 2. Récupère les one-hot + labels de chaque élément du batch,
# 3. Les renvoie sous forme de matrices NumPy prêtes pour le réseau.

# %%
def generate_batches(dataset, batch_size):
    """
    Génère des batchs successifs à partir du dataset.
    Chaque batch contient :
    - X_batch : tableau (batch_size, sentence_size, vocab_size)
    - y_batch : tableau (batch_size,)
    """
    for i in range(0, len(dataset), batch_size):
        batch_sentences = []
        batch_labels = []

        # On parcourt chaque échantillon du batch
        for j in range(i, min(i + batch_size, len(dataset))):
            x, y = dataset[j]
            batch_sentences.append(x)
            batch_labels.append(y)

        # On transforme en tableaux NumPy pour la compatibilité avec le réseau
        yield np.array(batch_sentences), np.array(batch_labels)

# %%
# Paramètres
sentence_size = 20
batch_size = 10

# Création de l’instance Dataset (notre version custom)
dataset = torch.utils.data.Dataset(texts, emotions, vocab, sentence_size)

print("🔹 Taille totale du dataset :", len(dataset))

# Exemple d’un échantillon unique
x0, y0 = dataset[0]
print("Phrase 0 encodée → shape :", x0.shape)
print("Label associé :", y0)

# Exemple d’un batch complet
for X_batch, y_batch in generate_batches(dataset, batch_size):
    print("\nBatch → X shape :", X_batch.shape)
    print("Batch → y shape :", y_batch.shape)
    print("Labels du batch :", y_batch[:5])
    break
# Out:
# 🔹 Taille totale du dataset : 16000
# Phrase 0 encodée → shape : (20, 15214)
# Label associé : 4
#
# Batch → X shape : (10, 20, 15214)
# Batch → y shape : (10,)
# Labels du batch : [4 4 0 3 0]

# %% [markdown]
# ### Partie 3

# %%
import numpy as np

class SimpleRNN:
    def __init__(self, input_size, hidden_size, output_size):
        """
        input_size  : taille du vecteur d'entrée (ex: vocab_size)
        hidden_size : taille du vecteur caché
        output_size : nombre de classes (émotions)
        """
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        # ⚙️ Poids entre input+hidden et hidden
        self.W_h = np.random.randn(hidden_size, input_size + hidden_size) * 0.01
        self.b_h = np.zeros((hidden_size, 1))

        # ⚙️ Poids entre input+hidden et output
        self.W_o = np.random.randn(output_size, input_size + hidden_size) * 0.01
        self.b_o = np.zeros((output_size, 1))

    def step(self, x_t, h_prev):
        """
        x_t     : vecteur d'entrée à l'instant t (shape: input_size, 1)
        h_prev  : état caché précédent (shape: hidden_size, 1)
        """
        # 1️⃣ Combine input + hidden précédent
        combined = np.vstack((x_t, h_prev))  # empile les deux vecteurs

        # 2️⃣ Nouveau hidden : tanh(W_h * combined + b_h)
        h_t = np.tanh(np.dot(self.W_h, combined) + self.b_h)

        # 3️⃣ Sortie brute : W_o * combined + b_o
        y_t = np.dot(self.W_o, combined) + self.b_o

        # 4️⃣ Application d’un softmax pour obtenir une "probabilité" de classe
        exp_y = np.exp(y_t - np.max(y_t))
        output = exp_y / exp_y.sum(axis=0, keepdims=True)

        return output, h_t

    def init_hidden(self):
        """Initialise le vecteur caché à zéro"""
        return np.zeros((self.hidden_size, 1))

# %%
vocab_size = 5     # (ex: 5 mots)
hidden_size = 4
output_size = 3     # (ex: 3 émotions)

rnn = SimpleRNN(vocab_size, hidden_size, output_size)
h = rnn.init_hidden()

# mot "i" → vecteur one-hot [1,0,0,0,0]
x_t = np.zeros((vocab_size, 1))
x_t[0,0] = 1.0

output, new_hidden = rnn.step(x_t, h)

print("Output (softmax):\n", output)
print("Hidden state:\n", new_hidden)
# Out:
# Output (softmax):
#  [[0.33213237]
#  [0.33720864]
#  [0.33065899]]
# Hidden state:
#  [[ 0.0096323 ]
#  [-0.00084202]
#  [-0.00563849]
#  [ 0.00080631]]

# %% [markdown]
# ### 🧪 Test 1 — Un mot unique (batch_size = 1, sans récurrence)
#
# Ici, on simule le passage d’un seul mot (comme ton sujet le dit).

# %%
# Sélection d'un mot du dataset
first_sentence = texts[0].split()
first_word = first_sentence[0]

# Création du vecteur one-hot
x_t = np.zeros((len(vocab), 1))
x_t[vocab.get(first_word, vocab["<UNK>"])] = 1.0

# Initialisation du réseau et du hidden state
vocab_size = len(vocab)
hidden_size = 64
output_size = len(set(emotions))

rnn = SimpleRNN(vocab_size, hidden_size, output_size)
h = rnn.init_hidden()

# Passage du mot unique
output, h_new = rnn.step(x_t, h)

print(f"Mot : {first_word}")
print("Output shape :", output.shape)
print("Hidden state shape :", h_new.shape)
print("Distribution de sortie :", output.ravel()[:5])

print("Somme des probabilités :", np.sum(output))
# Out:
# Mot : i
# Output shape : (6, 1)
# Hidden state shape : (64, 1)
# Distribution de sortie : [0.16804909 0.16854478 0.16707641 0.16709055 0.16373645]
# Somme des probabilités : 1.0000000000000002

# %% [markdown]
#  ### 🔁 Test 2 — Récurrence sur une phrase complète
#
# On va maintenant parcourir chaque mot d’une phrase du dataset, en faisant circuler le hidden à chaque étap

# %%
sentence = texts[0].split()
print("Phrase :", " ".join(sentence))

h = rnn.init_hidden()

for word in sentence:
    x_t = np.zeros((len(vocab), 1))
    x_t[vocab.get(word, vocab["<UNK>"])] = 1.0
    output, h = rnn.step(x_t, h)
    print(f"Étape {t} | mot = {word} | max proba sortie = {np.max(output):.4f}")

# Après avoir lu toute la phrase :
print("\nDernière sortie du RNN (probabilités normalisées) :")
print(output.ravel()[:5])
print("\nClasse prédite :", np.argmax(output))
# Out:
# Phrase : i didnt feel humiliated
# Étape 9 | mot = i | max proba sortie = 0.1685
# Étape 9 | mot = didnt | max proba sortie = 0.1686
# Étape 9 | mot = feel | max proba sortie = 0.1679
# Étape 9 | mot = humiliated | max proba sortie = 0.1692
#
# Dernière sortie du RNN (probabilités normalisées) :
# [0.16533468 0.16923704 0.16827448 0.16282174 0.16672551]
#
# Classe prédite : 1

# %% [markdown]
# ### 📦 Test 3 — Traitement par batch (plusieurs phrases)
#
# Maintenant, on simule un mini-batch de plusieurs phrases (par ex. 5 phrases du train).
#
# L’idée : toutes les phrases doivent avoir la même longueur → tu appliques ton pad_all_sentences() avant.

# %%
# On prend un mini-lot de phrases
batch_size = 5
sentence_size = 10
padded_sentences = pad_all_sentences(texts[:batch_size], sentence_size)

print("Batch de 5 phrases (paddées à 10 mots chacune)\n")

# Initialisation du hidden pour tout le batch
hidden_states = [rnn.init_hidden() for _ in range(batch_size)]


# Passage mot par mot (récurrence sur la longueur de la phrase)
for t in range(sentence_size):
    for i, sentence in enumerate(padded_sentences):
        word = sentence[t]
        x_t = np.zeros((len(vocab), 1))
        x_t[vocab.get(word, vocab["<UNK>"])] = 1.0
        _, hidden_states[i] = rnn.step(x_t, hidden_states[i])

print("✅ Passage batch terminé — hidden states mis à jour pour chaque phrase.")
# Out:
# Batch de 5 phrases (paddées à 10 mots chacune)
#
# ✅ Passage batch terminé — hidden states mis à jour pour chaque phrase.
